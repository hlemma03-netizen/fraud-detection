# %%
if "merged_df" not in globals():
    raise NameError(
        "merged_df is not defined. Execute the notebook cell that creates merged_df before this one."
    )

merged_df["time_since_signup"] = (
    merged_df["purchase_time"]
    - merged_df["signup_time"]
).dt.total_seconds()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 if "merged_df" not in globals():
#       2     if "merged_df" not in globals():
# ----> 3         raise NameError(
#       4             "merged_df is not defined. Execute the notebook cell that creates merged_df before this one."
#       5         )
#       6
#
# NameError: merged_df is not defined. Execute the notebook cell that creates merged_df before this one.

# %%
merged_df["hour_of_day"] = (
    merged_df["purchase_time"].dt.hour
)

# %%
merged_df["day_of_week"] = (
    merged_df["purchase_time"].dt.dayofweek
)

# %%
merged_df["transaction_count"] = (
    merged_df.groupby("user_id")
    ["user_id"]
    .transform("count")
)

# %%
merged_df["device_usage_count"] = (
    merged_df.groupby("device_id")
    ["device_id"]
    .transform("count")
)

# %%
categorical_cols = [
    "source",
    "browser",
    "sex",
    "country"
]

df_encoded = pd.get_dummies(
    merged_df,
    columns=categorical_cols,
    drop_first=True
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

num_cols = [
    "purchase_value",
    "age",
    "time_since_signup",
    "transaction_count",
    "device_usage_count"
]

df_encoded[num_cols] = scaler.fit_transform(
    df_encoded[num_cols]
)
